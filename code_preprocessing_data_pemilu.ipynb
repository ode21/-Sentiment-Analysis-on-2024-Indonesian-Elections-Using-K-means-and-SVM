# %% [markdown]
# # **Preprocessing Data**

# %% [markdown]
# 1. Import modul untuk pembersihan teks, tokenisasi, analisis teks, dan manipulasi data numerik jika diperlukan dalam proses preprocessing.

# %%
import pandas as pd
import numpy as np
import nltk
import string
import re

# %% [markdown]
# 2. Masukan file dataset yang akan diproses.

# %%
def load_data():
    data_tweets = pd.read_csv('pemilu.csv')
    return data_tweets

tweets = load_data()
tweets
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1    1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2    1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3    1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4    1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
# ..                   ...                             ...             ...
# 284  1780810929510424806  Thu Apr 18 04:44:36 +0000 2024              25
# 285  1783274272397644253  Wed Apr 24 23:18:12 +0000 2024              13
# 286  1781933252770677177  Sun Apr 21 06:29:31 +0000 2024               1
# 287  1783280277021978869  Wed Apr 24 23:42:04 +0000 2024              15
# 288  1783485324636893212  Thu Apr 25 13:16:51 +0000 2024               0
#
#                                              full_text               id_str  \
# 0     Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1    Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2    Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3    as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4    . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
# ..                                                 ...                  ...
# 284  @abu_waras @officialMKRI Kalo hakim mk memenan...  1780819698625786213
# 285  Pemilu 2024 telah berlalu namun tantangan baru...  1783274272397644253
# 286  Saatnya kita merajut kembali Persaudaraan kita...  1781933265429135782
# 287  Indonesia tetap Solid pasca Pemilu 2024 Tetap ...  1783280277021978869
# 288  Bhabinkamtibmas BRIPDA HAMKA selaku pokja penc...  1783485324636893212
#
#                                              image_url  \
# 0    https://pbs.twimg.com/ext_tw_video_thumb/17831...
# 1    https://pbs.twimg.com/ext_tw_video_thumb/17834...
# 2      https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg
# 3      https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg
# 4    https://pbs.twimg.com/ext_tw_video_thumb/17824...
# ..                                                 ...
# 284                                                NaN
# 285    https://pbs.twimg.com/media/GL92f7HbUAA-lp_.jpg
# 286  https://pbs.twimg.com/ext_tw_video_thumb/17819...
# 287    https://pbs.twimg.com/media/GL979EgasAAzq9N.jpg
# 288    https://pbs.twimg.com/media/GMA2c4hbgAAjhUk.jpg
#
#     in_reply_to_screen_name lang                 location  quote_count  \
# 0                       NaN   in                      NaN            0
# 1                       NaN   in   Jakarta Capital Region           10
# 2                       NaN   in       Jakarta, Indonesia          205
# 3                       NaN   en                Indonesia            3
# 4                       NaN   in  Social Media Influencer            4
# ..                      ...  ...                      ...          ...
# 284               abu_waras   in                      NaN            0
# 285                     NaN   in                      NaN            1
# 286         Jennife83085830   in                      NaN            6
# 287                     NaN   in                      NaN            1
# 288                     NaN   in                      NaN            0
#
#      reply_count  retweet_count  \
# 0              4             12
# 1             45              7
# 2            518           2998
# 3              7             77
# 4             69            174
# ..           ...            ...
# 284            5              4
# 285            3             12
# 286            0              0
# 287            2             15
# 288            0              0
#
#                                              tweet_url          user_id_str  \
# 0    https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1    https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2    https://twitter.com/erlanishere/status/1782758...             69561307
# 3    https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4    https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
# ..                                                 ...                  ...
# 284  https://twitter.com/put776/status/178081969862...  1570074569125535752
# 285  https://twitter.com/Anggita_lung/status/178327...           2907040202
# 286  https://twitter.com/Jennife83085830/status/178...  1562190652833923074
# 287  https://twitter.com/riegosee/status/1783280277...            988378254
# 288  https://twitter.com/UppWajo/status/17834853246...  1486163283896061955
#
#             username
# 0     dancersejati07
# 1     Mdy_Asmara1701
# 2        erlanishere
# 3         meihqtsume
# 4    StefanAntonio__
# ..               ...
# 284           put776
# 285     Anggita_lung
# 286  Jennife83085830
# 287         riegosee
# 288          UppWajo
#
# [289 rows x 15 columns]

# %% [markdown]
# 3. Cleaning.
# Disini ada dua tahapan cleaning; cleaning username, dan cleaning menghapus karakter tanda baca, emoticon, numerik, link dsb. Proses ini menggunakan loop dengan modul re.

# %%
#menghapus username dalam tweet
def remove_pattern(Text, pattern):
    r = re.findall(pattern, str(Text))
    for i in r:
        Text = re.sub(i, '', str(Text))
    return Text
tweets['remove_user'] = np.vectorize(remove_pattern)(tweets['full_text'], "@[\w]*")
tweets.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  reply_count  retweet_count  \
# 0   in                      NaN            0            4             12
# 1   in   Jakarta Capital Region           10           45              7
# 2   in       Jakarta, Indonesia          205          518           2998
# 3   en                Indonesia            3            7             77
# 4   in  Social Media Influencer            4           69            174
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...

# %%
#cleaning
def cleaning(Text):
    Text = re.sub(r'\$\w*', '', Text)         #digunakan untuk menghapus semua kata yang dimulai dengan tanda dolar ($) dan diikuti oleh karakter huruf, angka, atau garis bawah.      #
    Text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', ' ', Text)     #untuk menghapus semua URL atau tautan web dari teks.
    Text = re.sub('&quot;'," ", Text)         #Digunakan untuk menggantikan setiap kemunculan `&quot;` dengan spasi kosong dalam kolom `text`.
    Text = re.sub(r"\d+", " ", str(Text))         #digunakan untuk menggantikan semua angka dalam teks yang disimpan dalam kolom `text` dengan spasi kosong.
    Text = re.sub(r"\b[a-zA-Z]\b", "", str(Text))     #digunakan untuk menghapus semua kata tunggal dalam teks yang disimpan dalam kolom `text`.
    Text = re.sub(r"[^\w\s]", " ", str(Text))         #digunakan untuk menggantikan semua karakter non-alphanumerik dan non-spasi dalam teks yang disimpan dalam variabel `content` dengan spasi kosong.
    Text = re.sub(r'(.)\1+', r'\1\1', Text)         #Digunakan untuk mengganti dua atau lebih karakter berulang dalam teks dengan hanya dua karakter yang berulang. Misalnya, jika terdapat karakter berulang "eeeee" dalam teks, maka akan digantikan dengan "ee".
    Text = re.sub(r"\s+", " ", str(Text))       #digunakan untuk menggantikan satu atau lebih spasi berturut-turut dalam teks
    Text = re.sub(r'#', '', Text)         #digunakan untuk menghapus semua tanda pagar (#) dalam teks
    Text = re.sub(r'[^a-zA-z0-9]', ' ', str(Text))    #Digunakan untuk menggantikan semua karakter non-alphanumerik dalam teks dengan spasi kosong, sehingga menghapus karakter-karakter tersebut dari teks dan mempertahankan hanya huruf (kapital dan kecil) serta angka.
    Text = re.sub(r'\b\w{1,2}\b', '', Text)     #digunakan untuk menghapus kata-kata dengan panjang satu atau dua karakter dalam teks
    Text = re.sub(r'\s\s+', ' ', Text)      #Digunakan untuk menggantikan dua atau lebih spasi berturut-turut dalam teks dengan satu spasi tunggal.
    Text = re.sub(r'^RT[\s]+', '', Text)        #menghapus RT
    Text = re.sub(r'^b[\s]+', '', Text)       #digunakan untuk menghapus spasi di awal teks
    Text = re.sub(r'^link[\s]+', '', Text)      #digunakan untuk menghapus string "link" yang diikuti oleh spasi di awal teks
    return Text

def remove_emoji(Text):
    emoji = re.compile("["
                        u"\U0001F600-\U0001F64F"  # emoticons
                        u"\U0001F300-\U0001F5FF"  # simbol & piktogram
                        u"\U0001F680-\U0001F6FF"  # transportasi & simbol peralatan
                        u"\U0001F1E0-\U0001F1FF"  # bendera negara
                        u"\U00002702-\U000027B0"  # simbol
                        u"\U000024C2-\U0001F251"  # emoji lainnya
                        "]+", flags=re.UNICODE)
    return emoji.sub(r'', Text)

tweets['cleaning'] = tweets['remove_user'].apply(cleaning)
tweets.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  reply_count  retweet_count  \
# 0   in                      NaN            0            4             12
# 1   in   Jakarta Capital Region           10           45              7
# 2   in       Jakarta, Indonesia          205          518           2998
# 3   en                Indonesia            3            7             77
# 4   in  Social Media Influencer            4           69            174
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...

# %% [markdown]
# 4. Case Folding.
# Mengubah semua huruf besar menjadi huruf kecil menggunakan .str.lower()

# %%
#case folding - ubah jadi huruf kecil
tweets['case_folding'] = tweets['cleaning'].str.lower()
tweets.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  reply_count  retweet_count  \
# 0   in                      NaN            0            4             12
# 1   in   Jakarta Capital Region           10           45              7
# 2   in       Jakarta, Indonesia          205          518           2998
# 3   en                Indonesia            3            7             77
# 4   in  Social Media Influencer            4           69            174
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning  \
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...
#
#                                         case_folding
# 0   dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  breaking news pemilu usai saatnya bersama memb...
# 2  setelah keciduk foto ama zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   mereka telah menemukan caranya pemilu pemilu ...

# %% [markdown]
# 5. Tokenisasi/Tokenized.
# Mengubah data menjadi daftar kata-kata/list. Disini menggunakan Library dari NLTK dengan mengimport fungsi word_tokenize dari modul nltk.tokenize. Dan fungsi word_tokenize_wrapper digunakan dalam kode tersebut sebagai perantara (wrapper) yang memungkinkan kita menerapkan fungsi word_tokenize dari NLTK ke setiap baris teks.

# %%
#tokenisasi - membagi kalimat jadi perkata (dipisah)
nltk.download('punkt')
from nltk.tokenize import word_tokenize

def word_tokenize_wrapper(Tweets):
    return word_tokenize(Tweets)

tweets['tokenisasi'] = tweets['case_folding'].apply(lambda x: word_tokenize_wrapper(x.lower()))
tweets.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  reply_count  retweet_count  \
# 0   in                      NaN            0            4             12
# 1   in   Jakarta Capital Region           10           45              7
# 2   in       Jakarta, Indonesia          205          518           2998
# 3   en                Indonesia            3            7             77
# 4   in  Social Media Influencer            4           69            174
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning  \
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...
#
#                                         case_folding  \
# 0   dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  breaking news pemilu usai saatnya bersama memb...
# 2  setelah keciduk foto ama zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   mereka telah menemukan caranya pemilu pemilu ...
#
#                                           tokenisasi
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, ama, zionis, dan, sua...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...

# %% [markdown]
# 7. Normalisasi.
# Proses mengganti kalimat slang menjadi formal dengan menggunakan dan membaca dari kamus 'colloquial-indonesian-lexicon.csv'. Kamus ini berisi daftar kata-kata slang dan bentuk formalnya dalam bahasa Indonesia. Kemudian melakukan loop. Di dalam loop ini, setiap kata dalam teks dicek apakah ada dalam kamus dict_slang. Jika kata tersebut ada dalam kamus, maka kata slang akan diganti dengan bentuk formalnya sesuai dengan kamus. Jika kata tersebut tidak ada dalam kamus, kata tersebut tetap dipertahankan. **notes: untuk file 'colloquial-indonesian-lexicon.csv' mohon dimasukan kedalam notebook terlebih dahulu sebelum memproses preprocessing (*sama hal nya seperti memasukan file dataset csv yang akan diproses*)**

# %%
#Normalisasi-menormalisasikan kata yang non formal menjadi formal sesuai dengan kamus colloquial-indonesian-lexicon
def normalization (Tweets):
  tweets_slang = pd.read_csv('colloquial-indonesian-lexicon.csv')
  dict_slang ={}
  for i in range(tweets_slang.shape[0]):
    dict_slang[tweets_slang["slang"][i]]=tweets_slang["formal"][i]

  drop_slang = []
  for teks in Tweets:
    normalisasi_teks = [dict_slang[word] if word in dict_slang.keys() else word for word in teks]
    drop_slang.append(normalisasi_teks)

  return drop_slang

tweets['normalisasi'] = normalization(tweets['tokenisasi'])
tweets.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  reply_count  retweet_count  \
# 0   in                      NaN            0            4             12
# 1   in   Jakarta Capital Region           10           45              7
# 2   in       Jakarta, Indonesia          205          518           2998
# 3   en                Indonesia            3            7             77
# 4   in  Social Media Influencer            4           69            174
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning  \
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...
#
#                                         case_folding  \
# 0   dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  breaking news pemilu usai saatnya bersama memb...
# 2  setelah keciduk foto ama zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   mereka telah menemukan caranya pemilu pemilu ...
#
#                                           tokenisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, ama, zionis, dan, sua...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                          normalisasi
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, sama, zionis, dan, su...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...

# %% [markdown]
# 8. Stopword Removal/Removing. Menghapus kata yang tidak memiliki makna penting. Disini menggunakan Library dari NLTK dengan modul stopword dalam bahasa indonesia. from nltk.corpus import stopwords: Kode ini mengimpor daftar stopwords (kata-kata pengisi) dalam bahasa Indonesia dari NLTK. Daftar ini akan digunakan untuk mengidentifikasi kata-kata yang harus dihapus dari teks. Dan untuk code list_stopwords_id.extend: ini merupakan list tambahakan untuk menghapus kata yang tidak ada makna selain yang disediakan dalam corpus nltk stopword.

# %%
#Stopword removal - filtering/menghapus kata yang tidak ada didalam kamus corpus nltk
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

# Bahasa Indonesia stopwords
list_stopwords_id = stopwords.words('indonesian')
list_stopwords_id.extend(['yg', 'dg', 'rt', 'dgn', 'ny', 'gt', 'klo',
                       'kalo', 'amp', 'xbf', 'xad', 'xef',
                       'xe', 'ga', 'krn', 'nya', 'nih', 'sih',
                       'si', 'xc', 'tdk', 'tuh', 'utk', 'ya',
                       'jd', 'jgn', 'sdh', 'xae', 'n', 't',
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       '&', 'yah', 'no', 'je', 'xbb', 'xb', 'sch',
                       'injirrr', 'ah', 'oena', 'bu', 'eh', 'xac', 'xbc', 'xf', 'xa'])

list_stopwords = set(list_stopwords_id)

def stopwords_removal(Text):
    return [word for word in Text if word not in list_stopwords]

tweets['stopword_removal'] = tweets['normalisasi'].apply(stopwords_removal)
tweets.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  ...  retweet_count  \
# 0   in                      NaN            0  ...             12
# 1   in   Jakarta Capital Region           10  ...              7
# 2   in       Jakarta, Indonesia          205  ...           2998
# 3   en                Indonesia            3  ...             77
# 4   in  Social Media Influencer            4  ...            174
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning  \
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...
#
#                                         case_folding  \
# 0   dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  breaking news pemilu usai saatnya bersama memb...
# 2  setelah keciduk foto ama zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   mereka telah menemukan caranya pemilu pemilu ...
#
#                                           tokenisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, ama, zionis, dan, sua...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                          normalisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, sama, zionis, dan, su...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                     stopword_removal
# 0  [dana, bansos, pemilu, dikeluarkan, triliun, r...
# 1        [breaking, news, pemilu, membangun, negeri]
# 2  [keciduk, foto, zionis, suaranya, kena, boikot...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [menemukan, pemilu, pemilu, kedepan, tinggal, ...
#
# [5 rows x 21 columns]

# %% [markdown]
# 9. Stemming. Proses mengahpus imbuhan. Disini menggunakan Library sastrawi dahalam bahasa indonesia untuk menghapus imbuhannya. Modul stemmer digunakan untuk membuat objek stemmer. Sementara StopWordRemoverFactory membuat objek remover stopwords yang akan digunakan dalam tahap penghapusan, disini kasusnya seperti mengurangi noise, seperti "dan", "atau", "di", "dari", dll. Modul swifter disini berfungsi untuk mempercepat proses stemming.

# %%
#stemming - menghapus imbuhan
# !pip install swifter
# !pip install Sastrawi
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
import swifter

#buat stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

#stemmed wrapper
def stemmed_wrapper(term):
  return stemmer.stem(term)

term_dict = {}

for Tweets in tweets['stopword_removal']:
  for term in Tweets:
    if term not in term_dict:
      term_dict[term] = ' '

print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

#memmulai stemming
def apply_stemmed_term(Tweets):
  return [term_dict[term] for term in Tweets]

tweets['stemming'] = tweets['stopword_removal'].swifter.apply(apply_stemmed_term)
tweets.head()
# Out:
# Collecting swifter
#   Downloading swifter-1.4.0.tar.gz (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2.0.3)
# Requirement already satisfied: psutil>=5.6.6 in /usr/local/lib/python3.10/dist-packages (from swifter) (5.9.5)
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (2023.8.1)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.10/dist-packages (from swifter) (4.66.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2.2.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (2023.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (24.0)
# Requirement already satisfied: partd>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]>=2.10.0->swifter) (7.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.0->swifter) (1.25.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.18.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.2.0->dask[dataframe]>=2.10.0->swifter) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->swifter) (1.16.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.4.0-py3-none-any.whl size=16507 sha256=79ae3dbe35ebbe85b2ded9c99c354ebc296fdca79c61976eeb5ce79cad83b2ca
#   Stored in directory: /root/.cache/pip/wheels/e4/cf/51/0904952972ee2c7aa3709437065278dc534ec1b8d2ad41b443
# Successfully built swifter
# Installing collected packages: swifter
# Successfully installed swifter-1.4.0
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.3 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# 1813
# ------------------------
# dana : dana
# bansos : bansos
# pemilu : milu
# dikeluarkan : keluar
# triliun : triliun
# rupiah : rupiah
# biarkan : biar
# pejabat : jabat
# memenangkan : menang
# keluarganya : keluarga
# gelontorkan : gelontor
# uang : uang
# negara : negara
# eep : eep
# gulingkanrezimgarong : gulingkanrezimgarong
# breaking : breaking
# news : news
# membangun : bangun
# negeri : negeri
# keciduk : ciduk
# foto : foto
# zionis : zionis
# suaranya : suara
# kena : kena
# boikot : boikot
# pas : pas
# kemarin : kemarin
# ybs : ybs
# berusaha : usaha
# memperbaiki : baik
# citra : citra
# mendekati : dekat
# palestina : palestina
# comes : comes
# end : end
# ending : ending
# too : too
# little : little
# finale : finale
# close : close
# jagat : jagat
# silang : silang
# edisi : edisi
# khusus : khusus
# zine : zine
# artbook : artbook
# pages : pages
# all : all
# editorial : editorial
# art : art
# posted : posted
# doodles : doodles
# wips : wips
# concepts : concepts
# essays : essays
# experience : experience
# peeks : peeks
# get : get
# below : below
# menemukan : temu
# kedepan : depan
# tinggal : tinggal
# disempurnakan : sempurna
# era : era
# orde : orde
# barupun : baru
# terulang : ulang
# pemenang : menang
# ditentukan : tentu
# dilaksanakan : laksana
# rakyat : rakyat
# dipelihara : pelihara
# miskin : miskin
# bodoh : bodoh
# kemenangan : menang
# nepotisme : nepotisme
# tau : tau
# bikin : bikin
# kali : kali
# seru : seru
# banget : banget
# orang : orang
# interest : interest
# politik : politik
# melek : melek
# data : data
# fakta : fakta
# melawan : lawan
# penguasa : kuasa
# haus : haus
# kekuasaan : kuasa
# bangga : bangga
# dibarisan : baris
# apapun : apa
# telh : telh
# upayakan : upaya
# trimakasih : trimakasih
# rocky : rocky
# gerung : gerung
# bicara : bicara
# hasil : hasil
# putusan : putus
# desending : desending
# ajaib : ajaib
# hakim : hakim
# curang : curang
# cacat : cacat
# bawaan : bawa
# mempertahankan : tahan
# dalil : dalil
# diputus : putus
# paman : paman
# usman : usman
# watch : watch
# alhamdulillah : alhamdulillah
# prabowo : prabowo
# gibran : gibran
# resmi : resmi
# ditetapkan : tetap
# kpu : kpu
# presiden : presiden
# wakil : wakil
# terpilih : pilih
# periode : periode
# terima : terima
# kasih : kasih
# indonesia : indonesia
# penyelenggara : selenggara
# tokoh : tokoh
# agama : agama
# prajurit : prajurit
# tni : tni
# polri : polri
# relawan : rawan
# rekan : rekan
# pers : pers
# jongos : jongos
# celeng : celeng
# lupa : lupa
# jejak : jejak
# digital : digital
# wowo : wowo
# menuntut : tuntut
# kepanasan : panas
# surat : surat
# amicus : amicus
# curiaenya : curiaenya
# mega : mega
# menjelang : jelang
# juta : juta
# dibagikan : bagi
# kepala : kepala
# mestinya : mesti
# ribu : ribu
# beras : beras
# larinya : lari
# menang : menang
# kerusuhan : rusuh
# kalah : kalah
# mati : mati
# luka : luka
# ketahuan : tahu
# kekalahan : kalah
# kumpulnya : kumpul
# kubu : kubu
# mantan : mantan
# pendukung : dukung
# anies : anies
# demo : demo
# tolak : tolak
# intervensi : intervensi
# patung : patung
# kuda : kuda
# tempo : tempo
# febri : febri
# angga : angga
# palguna : palguna
# tempofoto : tempofoto
# lahirlah : lahir
# sistem : sistem
# buruk : buruk
# prinsip : prinsip
# lakukanlah : laku
# securang : curang
# tanggung : tanggung
# gentonglah : gentong
# segentong : gentong
# gentongnya : gentong
# babilah : babi
# sebabi : sebab
# babinya : babi
# hamid : hamid
# seremoni : seremoni
# focus : focus
# presidenterpilih : presidenterpilih
# text : text
# kenaikan : naik
# gaji : gaji
# asn : asn
# dicairkan : cair
# melaksanakan : laksana
# keputusan : putus
# diskuwalifikasikan : diskuwalifikasikan
# ulang : ulang
# hormati : hormat
# pilpres : pilpres
# mandat : mandat
# low : low
# effort : effort
# edit : edit
# guys : guys
# understand : understand
# will : will
# become : become
# tinta : tinta
# pandan : pandan
# without : without
# topi : topi
# terbukti : bukti
# pelaksanaan : laksana
# kecurangan : curang
# brutal : brutal
# dipimpin : pimpin
# manusia : manusia
# banggalah : bangga
# anak : anak
# cucu : cucu
# pemanis : man
# buatan : buat
# pengadilan : adil
# tata : tata
# usaha : usaha
# gugatan : gugat
# pdip : pdip
# saldi : saldi
# isra : isra
# lembaga : lembaga
# menyelesaikan : selesai
# berkaitan : kait
# diserahkan : serah
# menganggap : anggap
# keranjang : keranjang
# sampah : sampah
# breakingnewsmetrotv : breakingnewsmetrotv
# sidangmk : sidangmk
# sidangputusanmk : sidangputusanmk
# aniesmuhaimin : aniesmuhaimin
# dunia : dunia
# kampus : kampus
# marah : marah
# pelanggaran : langgar
# moral : moral
# etik : etik
# lakukan : laku
# gue : gue
# sedih : sedih
# keluarnya : keluar
# actually : actually
# over : over
# kampanye : kampanye
# pesta : pesta
# demokrasi : demokrasi
# more : more
# luruskan : lurus
# angka : angka
# golput : golput
# muncul : muncul
# alat : alat
# rekap : rekap
# perhitungannya : hitung
# selesai : selesai
# sengketa : sengketa
# dimenangkan : menang
# nestapa : nestapa
# pks : pks
# anggota : anggota
# dpr : dpr
# dukung : dukung
# hak : hak
# angket : angket
# dirty : dirty
# vote : vote
# menargetkan : target
# putaran : putar
# persen : persen
# melibatkan : libat
# salah : salah
# tangan : tangan
# legal : legal
# engkau : engkau
# dustakan : dusta
# perselisihan : selisih
# akal : akal
# sehat : sehat
# ylbhi : ylbhi
# menilai : nilai
# terkait : kait
# pemilihan : pilih
# hukum : hukum
# bukti : bukti
# nyata : nyata
# kegagalan : gagal
# penjaga : jaga
# kedaulatan : daulat
# konstitusi : konstitusi
# dissenting : dissenting
# opinion : opinion
# didukung : dukung
# menaikkan : naik
# suara : suara
# nasdem : nasdem
# update : update
# penyaluran : salur
# jelang : jelang
# jokowi : jokowi
# menteri : menteri
# menguntungkan : untung
# pasangan : pasang
# calon : calon
# tempodotco : tempodotco
# dungu : dungu
# blunder : blunder
# komisioner : komisioner
# undang : undang
# mengenal : kenal
# curiae : curiae
# turunkanrampoknegara : turunkanrampoknegara
# himbauan : himbauan
# mari : mari
# bergandeng : gandeng
# lupakan : lupa
# perbedaan : beda
# pandangan : pandang
# bersatu : satu
# makan : makan
# sekolah : sekolah
# diperalat : alat
# bayaran : bayar
# pro : pro
# anehnya : aneh
# menolak : tolak
# pintar : pintar
# dek : dek
# pakai : pakai
# otak : otak
# hatimu : hati
# pegang : pegang
# pakar : pakar
# ugm : ugm
# zainal : zainal
# arifin : arifin
# mochtar : mochtar
# mendorong : dorong
# menurutnya : turut
# proses : proses
# keliru : keliru
# dibiarkan : biar
# hnw : hnw
# ingatkan : ingat
# hadis : hadis
# berani : berani
# memutuskan : putus
# adil : adil
# selamat : selamat
# kepercayaan : percaya
# thd : thd
# ajukan : aju
# guru : guru
# ilmu : ilmu
# idolaku : idola
# posisi : posisi
# permohonan : mohon
# uji : uji
# formil : formil
# omnibus : omnibus
# law : law
# kesehatan : sehat
# sidang : sidang
# prof : prof
# contoh : contoh
# gua : gua
# serius : serius
# jalan : jalan
# kerja : kerja
# suka : suka
# menyelidiki : selidik
# power : power
# sharing : sharing
# masuk : masuk
# surga : surga
# wajar : wajar
# logis : logis
# jabatan : jabat
# kabinet : kabinet
# partai : partai
# mendukung : dukung
# dibagi : bagi
# mengapai : kapai
# repot : repot
# pilkada : pilkada
# penenangnya : tenang
# demokrasiwajibcurang : demokrasiwajibcurang
# now : now
# live : live
# pembacaan : baca
# phpu : phpu
# mahkamah : mahkamah
# ptun : ptun
# pencalonan : calon
# pertanyaannya : tanya
# knapa : knapa
# ketua : ketua
# puan : puan
# sinyal : sinyal
# jadikan : jadi
# cawapres : cawapres
# takut : takut
# bts : bts
# harun : harun
# masiku : mas
# angkat : angkat
# berisik : berisik
# bawa : bawa
# tameng : tameng
# hitung : hitung
# kekuatan : kuat
# parpol : parpol
# gulirkan : gulir
# klynews : klynews
# ketuai : ketua
# hasyim : hasyim
# azhari : azhari
# layak : layak
# menyelenggarakan : selenggara
# legislatif : legislatif
# qoda : qoda
# takdir : takdir
# allah : allah
# qodar : qodar
# ketentuan : tentu
# swt : swt
# qodari : qodari
# menentukan : tentu
# serangkaian : rangkai
# drama : drama
# rezim : rezim
# statement : statement
# kemenangannya : menang
# gara : gara
# tuduhan : tuduh
# kejam : kejam
# menuduh : tuduh
# mengintervensi : intervensi
# perasaanrakyatdesa : perasaanrakyatdesa
# berbeda : beda
# ketiga : tiga
# sembarangan : sembarang
# berijazah : ijazah
# asali : asali
# mikir : mikir
# sesat : sesat
# logika : logika
# kepceran : kepceran
# kiri : kiri
# hubungan : hubung
# pilihan : pilih
# pemilih : pilih
# kanan : kanan
# obrolan : obrol
# pagi : pagi
# jaman : jaman
# berotak : otak
# kehilangan : hilang
# terbaik : baik
# keilangan : keilangan
# kewarasan : waras
# jegal : jegal
# habis : habis
# pendaftaran : daftar
# menangpun : menang
# diupayakan : upaya
# gagal : gagal
# batal : batal
# diskualifikasi : diskualifikasi
# rame : rame
# diulang : ulang
# ngeri : ngeri
# korupsi : korupsi
# dibongkar : bongkar
# dihabisi : habis
# ampun : ampun
# hope : hope
# you : you
# don : don
# only : only
# guy : guy
# but : but
# also : also
# persona : persona
# membagongkan : bagong
# pendapat : dapat
# bang : bang
# fundamental : fundamental
# opisisi : opisisi
# check : check
# and : and
# balancingnya : balancingnya
# ikutan : ikut
# pemerintahan : perintah
# maknanya : makna
# melanggar : langgar
# kip : kip
# total : total
# paslon : paslon
# sirekap : sirekap
# klaim : klaim
# pesan : pesan
# apresiasi : apresiasi
# abah : abah
# cak : cak
# muda : muda
# menyemarakkan : semarak
# insyaallah : insyaallah
# humanies : humanies
# project : project
# komunitas : komunitas
# lahir : lahir
# semangat : semangat
# perubahan : ubah
# berjalan : jalan
# melewati : lewat
# jujur : jujur
# kelen : kelen
# percaya : percaya
# temponasional : temponasional
# mendengarkan : dengar
# noh : noh
# lobet : lobet
# ketum : tum
# ambisi : ambisi
# berkuasa : kuasa
# lu : lu
# gerakan : gera
# harapan : harap
# gagasan : gagas
# bertumbuh : tumbuh
# ruang : ruang
# aktivitas : aktivitas
# kesempatan : sempat
# arief : arief
# terang : terang
# terangan : terang
# banteng : banteng
# kompak : kompak
# menghadiri : hadir
# penetapan : tetap
# ogah : ogah
# kabulkan : kabul
# permintaan : minta
# menunda : tunda
# buatlah : buat
# fitnah : fitnah
# jahat : jahat
# undangan : undang
# muhaimin : muhaimin
# ganjar : ganjar
# mahfud : mahfud
# optimistis : optimistis
# mengabulkan : kabul
# indikasinya : indikasi
# follow : follow
# tiktok : tiktok
# konten : konten
# video : video
# lambe : lambe
# waras : waras
# malu : malu
# dibatalkan : batal
# pemimpin : pimpin
# diberitahu : diberitahu
# faham : faham
# putusanmk : putusanmk
# perempuan : perempuan
# seruan : seru
# selamatkan : selamat
# berkeadilan : adil
# mahkamahkonstitusi : mahkamahkonstitusi
# senin : senin
# mall : mall
# surabaya : surabaya
# junction : junction
# serentak : serentak
# menyayikan : menyayikan
# tanah : tanah
# airku : air
# meneguhkan : teguh
# memutus : putus
# hadir : hadir
# kompetisi : kompetisi
# pelajaran : ajar
# barisan : baris
# mas : mas
# hasilnya : hasil
# kritik : kritik
# fun : fun
# fact : fact
# sejarah : sejarah
# presidennya : presiden
# pelanggar : langgar
# ham : ham
# wapresnya : wapresnya
# aroma : aroma
# kental : kental
# diduga : duga
# asusila : asusila
# berkali : kali
# kode : kode
# tetaplah : tetap
# beretika : etika
# pelanggan : langgan
# prosedural : prosedural
# refly : refly
# pileg : pileg
# kejahatan : jahat
# konspirasi : konspirasi
# meloloskan : lolos
# menyimak : simak
# melongo : longo
# dukungan : dukung
# wallpaper : wallpaper
# harmoni : harmoni
# damai : damai
# balai : balai
# sarbini : sarbini
# debat : debat
# setuju : tuju
# berguna : guna
# gagasannya : gagas
# joget : joget
# kampanyenya : kampanye
# pov : pov
# unair : unair
# its : its
# mmbawa : mmbawa
# rivalitas : rivalitas
# duel : duel
# gsm : gsm
# design : design
# survey : survey
# indikator : indikator
# rajin : rajin
# rilis : rilis
# deh : deh
# nemu : nemu
# temanya : tema
# kepuasan : puas
# kinerja : kerja
# psu : psu
# penyelenggaraan : selenggara
# coba : coba
# takan : tak
# adudomba : adudomba
# udomba : udomba
# oknum : oknum
# menggagalkan : gagal
# terlibat : libat
# kkn : kkn
# diproses : proses
# kontrak : kontrak
# mou : mou
# menjual : jual
# asset : asset
# bangsa : bangsa
# ngritik : ngritik
# urusan : urus
# ditantang : tantang
# papua : papua
# menasihati : nasihat
# buruknya : buruk
# efek : efek
# merokok : rokok
# gunung : gunung
# paru : paru
# netralitas : netralitas
# dituding : tuding
# partisan : partisan
# disuruh : suruh
# politisi : politis
# peduli : peduli
# campur : campur
# takkan : tak
# indonsia : indonsia
# adakah : ada
# kaitannya : kait
# wakanda : wakanda
# dubai : dubai
# tol : tol
# laut : laut
# demak : demak
# tim : tim
# amin : amin
# menyerahkan : serah
# materi : materi
# kesimpulan : simpul
# bismillah : bismillah
# dimudahkan : mudah
# dilancarkan : lancar
# joki : joki
# kewarganegaraan : kewarganegaraan
# artikel : artikel
# zonauang : zonauang
# kuasa : kuasa
# yusril : yusril
# ihza : ihza
# mahendra : mahendra
# jajaran : jajar
# menyambangi : sambang
# rumah : rumah
# subianto : subianto
# melaporkan : lapor
# selasa : selasa
# prabowogibran : prabowogibran
# berdemo : demo
# telak : telak
# signifikan : signifikan
# mesti : mesti
# kawal : kawal
# murni : murni
# dilaporkan : lapor
# dugaan : duga
# korbannya : korban
# petugas : tugas
# bem : bem
# fakultas : fakultas
# universitas : universitas
# gadjah : gadjah
# mada : mada
# diponegoro : diponegoro
# padjadjaran : padjadjaran
# airlangga : airlangga
# amici : amici
# mahasiswa : mahasiswa
# batalkan : batal
# pdi : pdi
# perjuangan : juang
# pdiperjuangan : pdiperjuangan
# nangkanrakyat : nangkanrakyat
# kebenaranpastimenang : kebenaranpastimenang
# satyamevajayate : satyamevajayate
# need : need
# tugas : tugas
# deadline : deadline
# besok : besok
# cari : cari
# jokitugas : jokitugas
# berperkara : perkara
# putuskan : putus
# jokowibapaknepotisme : jokowibapaknepotisme
# biang : biang
# kerok : kerok
# sumber : sumber
# repoblik : repoblik
# ijazah : ijazah
# palsu : palsu
# pundaknya : pundak
# jokowipenipurakyatnya : jokowipenipurakyatnya
# matanya : mata
# bersinar : sinar
# hidayat : hidayat
# support : support
# kejanggalan : janggal
# dasarnya : dasar
# sekedar : dar
# peserta : serta
# capres : capres
# mengedukasi : edukasi
# berlaku : laku
# sportivitas : sportivitas
# wow : wow
# menyaksikan : saksi
# dikorupsi : korupsi
# ratusan : ratus
# chaos : chaos
# cuman : cuman
# indak : indak
# namanya : nama
# biaya : biaya
# setaik : setaik
# kukunya : kuku
# dibanding : banding
# timah : timah
# pembagian : bagi
# rekomendasikan : rekomendasi
# konsisten : konsisten
# menangis : menang
# pleno : pleno
# rabu : rabu
# april : april
# pidato : pidato
# menyalami : salam
# momen : momen
# berkaca : kaca
# kaca : kaca
# aktivis : aktivis
# menyoroti : sorot
# praktek : praktek
# merajalela : rajalela
# keprihatinannya : prihatin
# degradasi : degradasi
# desakperiksajokowi : desakperiksajokowi
# iya : iya
# maju : maju
# pimpinannya : pimpin
# pelayanan : layan
# aseng : aseng
# asing : asing
# ngeruk : ngeruk
# alam : alam
# ugal : ugal
# pembuktian : bukti
# oke : oke
# cont : cont
# siagalah : siaga
# pilbup : pilbup
# pilgub : pilgub
# patut : patut
# duga : duga
# pura : pura
# berdemokrasi : demokrasi
# oligarki : oligarki
# kapitalis : kapitalis
# aparat : aparat
# survei : survei
# quick : quick
# countnya : countnya
# tayang : tayang
# berpartisipasi : partisipasi
# next : next
# pribadi : pribadi
# ambil : ambil
# sikap : sikap
# berpengaruh : pengaruh
# revisi : revisi
# aturan : atur
# dicontohkan : contoh
# menormalisasi : normalisasi
# penjabat : jabat
# meneruskan : terus
# galau : galau
# gugat : gugat
# newsflash : newsflash
# diawal : awal
# saking : saking
# jujurnya : jujur
# menanggapi : tanggap
# politisasi : politisasi
# mobilisasi : mobilisasi
# aparatur : aparatur
# beralasan : alas
# pilih : pilih
# paloh : paloh
# kuat : kuat
# oposisi : oposisi
# mengikat : ikat
# ayomoveon : ayomoveon
# keadilan : adil
# pemilujujur : pemilujujur
# pemiluindonesia : pemiluindonesia
# officially : officially
# declared : declared
# president : president
# vice : vice
# for : for
# the : the
# term : term
# curiea : curiea
# abaikan : abai
# teriak : teriak
# olah : olah
# golongan : golong
# pembela : bela
# hargai : harga
# berdampak : dampak
# erga : erga
# omnes : omnes
# anggap : anggap
# pemerintah : perintah
# langgar : langgar
# terstruktur : struktur
# sistematis : sistematis
# menghasilkan : hasil
# luarr : luarr
# biasaahh : biasaahh
# tok : tok
# becus : becus
# amburadul : amburadul
# strategi : strategi
# unk : unk
# menggiring : giring
# opini : opini
# legowo : legowo
# pendukungnya : dukung
# kericuhan : ricuh
# pendamping : damping
# liaison : liaison
# feb : feb
# pengumuman : umum
# maret : maret
# dihari : hari
# biru : biru
# joko : joko
# widodo : widodo
# ucapkan : ucap
# republik : republik
# kepemimpinannya : pimpin
# open : open
# review : review
# halaman : halaman
# full : full
# drop : drop
# fee : fee
# zonajajan : zonajajan
# zonabeli : zonabeli
# zonaba : zonaba
# tumpuan : tumpu
# penyelesaian : selesai
# sebgai : sebgai
# konstitusionalnya : konstitusional
# interpelasi : interpelasi
# berpendapat : dapat
# megawati : megawati
# serahkan : serah
# merah : merah
# tepatnya : tepat
# tanggal : tanggal
# menuliskan : tulis
# berwarna : warna
# istilah : istilah
# disenting : senting
# absolut : absolut
# pemilunya : milu
# dinasti : dinasti
# menemani : tani
# bertemu : temu
# semoga : moga
# gratis : gratis
# kaum : kaum
# meniru : tiru
# wasit : wasit
# protes : protes
# mkmkmk : mkmkmk
# aman : aman
# tertib : tertib
# terselenggara : selenggara
# jakarta : jakarta
# jogjakarta : jogjakarta
# jumat : jumat
# pekan : pekan
# rekomendasi : rekomendasi
# singgung : singgung
# cawe : cawe
# arif : arif
# eny : eny
# prov : prov
# dki : dki
# jabar : jabar
# jateng : jateng
# jatim : jatim
# bali : bal
# sumut : sumut
# buta : buta
# matahati : matahati
# tuhan : tuhan
# dianggap : anggap
# sarapanfotooshi : sarapanfotooshi
# dikucurkan : kucur
# mengubah : ubah
# pkpu : pkpu
# menerima : terima
# memverifikasi : verifikasi
# gibr : gibr
# jurdil : jurdil
# berdasarkan : dasar
# mendiskualifikasi : diskualifikasi
# rudal : rudal
# diluncurkan : luncur
# berdoa : doa
# dicurangi : curang
# kontestasi : kontestasi
# berat : berat
# min : min
# korban : korban
# pelaku : laku
# membahayakan : bahaya
# tekankan : tekan
# penyempurnaan : sempurna
# reaksi : reaksi
# teroris : teroris
# limpol : limpol
# dikasih : kasih
# coblos : coblos
# perak : perak
# harga : harga
# kontol : kontol
# lobang : lobang
# pantat : pantat
# betaik : betaik
# isi : isi
# februari : februari
# ahli : ahli
# prediktif : prediktif
# variabel : variabel
# tunjukkan : tunjuk
# terlepas : lepas
# taktik : taktik
# mrpk : mrpk
# copycat : copycat
# demograzy : demograzy
# silakan : sila
# caee : caee
# fasilitas : fasilitas
# sukalah : suka
# sesungguhnya : sungguh
# kedewasaan : dewasa
# berpolitik : politik
# istimewa : istimewa
# hormat : hormat
# berdua : dua
# baiknya : baik
# penolong : tolong
# prabowopresiden : prabowopresiden
# penuh : penuh
# warna : warna
# sesuai : sesuai
# bhabinkamtibmas : bhabinkamtibmas
# briptu : briptu
# arisandi : arisandi
# pokja : pokja
# pencegahan : cegah
# giat : giat
# sambang : sambang
# lingk : lingk
# menge : menge
# keluarga : keluarga
# belawa : bawa
# kec : kec
# kamtibmas : kamtibmas
# bijak : bijak
# sosialisasi : sosialisasi
# perpres : pres
# sapu : sapu
# bersih : bersih
# pungutan : pungut
# liar : liar
# pungli : pungli
# bawaslu : bawaslu
# dkpp : dkpp
# selengkapnya : lengkap
# simak : simak
# penjelasannya : jelas
# terdiam : diam
# tersenyum : senyum
# ditolak : tolak
# dll : dll
# genggaman : genggam
# dikemudian : kemudi
# wajib : wajib
# dihormati : hormat
# ketidak : tidak
# percayaan : percaya
# trhdp : trhdp
# sah : sah
# pikir : pikir
# logikanya : logika
# dimana : mana
# yth : yth
# tertawa : tertawa
# democrazy : democrazy
# mengakui : aku
# syah : syah
# tsm : tsm
# kayak : kayak
# kentut : kentut
# cium : cium
# baunya : bau
# keluarkan : keluar
# gasnya : gas
# susah : susah
# dibuktikan : bukti
# kecuali : kecuali
# langsung : langsung
# lubang : lubang
# sumbernya : sumber
# konsumsi : konsumsi
# elite : elite
# kelompok : kelompok
# terafiliasi : afiliasi
# adi : adi
# prayitno : prayitno
# masyarakat : masyarakat
# mengumumkan : umum
# gambar : gambar
# tkn : tkn
# tas : tas
# teriakan : ria
# nyapres : nyapres
# hamdan : hamdan
# zoelva : zoelva
# dinastigarongapbn : dinastigarongapbn
# amplop : amplop
# berkualitas : kualitas
# memilih : pilih
# psi : psi
# huraa : huraa
# sudii : sudi
# india : india
# melangsungkan : langsung
# terbesar : besar
# terlama : lama
# diikuti : ikut
# miliar : miliar
# minggu : minggu
# caleg : caleg
# tamil : tamil
# nadu : nadu
# naah : naah
# ngeles : ngeles
# what : what
# did : did
# not : not
# realize : realize
# that : that
# there : there
# are : are
# areas : areas
# within : within
# our : our
# government : government
# landscape : landscape
# already : already
# built : built
# their : their
# mobile : mobile
# web : web
# apps : apps
# with : with
# user : user
# centric : centric
# quality : quality
# research : research
# konteks : konteks
# berkontribusi : kontribusi
# teknologi : teknologi
# kesuksesan : sukses
# dukungpemilu : dukungpemilu
# hormatiputusanmk : hormatiputusanmk
# sukseskanpemilu : sukseskanpemilu
# catatan : catat
# bahan : bahan
# evaluasi : evaluasi
# beda : beda
# sindir : sindir
# lbp : lbp
# bhirawa : bhirawa
# jayasidayatra : jayasidayatra
# arifi : arif
# perwakilan : wakil
# pengacara : acara
# temuan : temu
# tercoblos : coblos
# dinilai : nilai
# bermasalah : masalah
# layaknya : layak
# daerah : daerah
# terindikasi : indikasi
# sakaw : sakaw
# ngebleng : ngebleng
# berdekatan : dekat
# ridwan : ridwan
# mansyur : mansyur
# anjurkan : anjur
# batalin : batalin
# pasal : pasal
# anti : anti
# argumennya : argumen
# salahkan : salah
# kerabat : kerabat
# incumbent : incumbent
# berkompetisi : kompetisi
# awasi : awas
# petahana : tahana
# kerabatnya : kerabat
# susahnya : susah
# membuktikan : bukti
# reading : reading
# old : old
# tweets : tweets
# omg : omg
# miss : miss
# temanpemilih : temanpemilih
# menggelar : gelar
# rapat : rapat
# terbuka : buka
# utama : utama
# lantai : lantai
# kantor : kantor
# asy : asy
# ari : ari
# memimpin : pimpin
# didampingi : damping
# idham : idham
# holik : holik
# massa : massa
# gelar : gelar
# tuntut : tuntut
# siang : siang
# haram : haram
# gabung : gabung
# koalisi : koalisi
# some : some
# preview : preview
# inside : inside
# berita : berita
# star : star
# this : this
# compiled : compiled
# into : into
# one : one
# description : description
# meaning : meaning
# story : story
# behind : behind
# process : process
# making : making
# concept : concept
# sketch : sketch
# perbaikan : baik
# rujukan : rujuk
# wanti : wanti
# penuding : tuding
# pengamat : amat
# kau : kau
# mudah : mudah
# terprovokasi : provokasi
# pemberitaan : berita
# negatif : negatif
# pasca : pasca
# kondusif : kondusif
# dipihaki : pihak
# istana : istana
# perkuat : kuat
# persatuan : satu
# kesatuan : satu
# amandamai : amandamai
# wujudkanpemiludamai : wujudkanpemiludamai
# tonton : tonton
# film : film
# election : election
# isinya : isi
# panggilan : panggil
# revolusi : revolusi
# asa : asa
# membumbung : bumbung
# etika : etika
# mkjgnrusakbahagiarakyat : mkjgnrusakbahagiarakyat
# dosen : dosen
# kampungan : kampung
# mengindahkan : indah
# menghargai : harga
# institusi : institusi
# dipimpinnya : pimpin
# walhasil : walhasil
# tindak : tindak
# adu : adu
# argumen : argumen
# ngopi : ngopi
# nyantai : nyantai
# baca : baca
# buku : buku
# provokasi : provokasi
# ayo : ayo
# sudahi : sudah
# saudara : saudara
# inshaallah : inshaallah
# tudingan : tuding
# prabowopresidenbansos : prabowopresidenbansos
# mencolong : colong
# duit : duit
# buang : buang
# bloon : bloon
# sukses : sukses
# keren : keren
# tiidak : tiidak
# insya : insya
# beliau : beliau
# berintegritas : integritas
# rekonsiliasi : rekonsiliasi
# dibutuhkan : butuh
# situasi : situasi
# persaingan : saing
# seringkali : seringkali
# meninggalkan : tinggal
# ketegangan : tegang
# perpecahan : pecah
# elit : elit
# maribersatu_pascapemilu : maribersatu pascapemilu
# tobrut : tobrut
# liverpool : liverpool
# qatar : qatar
# towel : towel
# pramestia : pramestia
# satria : satria
# plz : plz
# persidangan : sidang
# pkb : pkb
# sprtinya : sprtinya
# memanfaatkan : manfaat
# isu : isu
# tujuan : tuju
# kompromi : kompromi
# bermanuver : manuver
# harusrevolusi : harusrevolusi
# licik : licik
# menipu : tipu
# munculkan : muncul
# sulit : sulit
# membayangkan : bayang
# implementasi : implementasi
# merujuk : rujuk
# pertimbangan : timbang
# how : how
# was : was
# draw : draw
# these : these
# technically : technically
# being : being
# part : part
# indogov : indogov
# fandom : fandom
# why : why
# choose : choose
# here : here
# your : your
# views : views
# change : change
# guess : guess
# honest : honest
# thoughts : thoughts
# have : have
# agree : agree
# ribut : ribut
# jaga : jaga
# bebashoaks : bebashoaks
# pemiludamai : pemiludamai
# menujuindonesiamaju : menujuindonesiamaju
# pemiludamainegerimaju : pemiludamainegerimaju
# halo : halo
# internasional : internasional
# menghormati : hormat
# bentuk : bentuk
# pilpresusai_kitaberdamai : pilpresusai kitaberdamai
# barca : barca
# araujo : araujo
# xavi : xavi
# barcelona : barcelona
# menyambut : sambut
# mrupakan : mrupakan
# kewajiban : wajib
# trjdi : trjdi
# gesekan : gesek
# maribersatu_usaipemilu : maribersatu usaipemilu
# haaland : haaland
# madrid : madrid
# kbr : kbr
# galak : galak
# angin : angin
# gincu : gincu
# arah : arah
# kacau : kacau
# rencana : rencana
# digulirkan : gulir
# ndeso : ndeso
# lihat : lihat
# menggelontor : gelontor
# kroso : kroso
# sono : sono
# opo : opo
# masak : masak
# atimu : ati
# iku : iku
# ndi : ndi
# kim : kim
# merugikan : rugi
# upaya : upaya
# melokalisir : melokalisir
# ditempatkan : tempat
# titik : titik
# berhenti : henti
# bersikap : sikap
# jentelmen : jentelmen
# bongkar : bongkar
# tbijihnikel : tbijihnikel
# ilegal : ilegal
# etis : etis
# memahami : paham
# acara : acara
# peraturan : atur
# komisi : komisi
# informasi : informasi
# keberatan : berat
# diajukan : aju
# bahagia : bahagia
# semalem : semalem
# tinmas : tinmas
# rakyatmenang : rakyatmenang
# diluar : luar
# undeniably : undeniably
# great : great
# father : father
# figure : figure
# wish : wish
# had : had
# want : want
# future : future
# kids : kids
# thank : thank
# efforts : efforts
# rest : rest
# timnas : timnas
# can : can
# after : after
# continue : continue
# goodness : goodness
# always : always
# stay : stay
# healthy : healthy
# membawa : bawa
# nuansa : nuansa
# bertepata : bertepata
# kartini : kartini
# civitas : civitas
# akademika : akademika
# pernyataan : nyata
# bersifat : sifat
# final : final
# diterima : terima
# hati : hati
# lapang : lapang
# dada : dada
# legawa : legawa
# langkah : langkah
# menciptakan : cipta
# perdamaian : damai
# mewujudkan : wujud
# merdeka : merdeka
# berdaulat : daulat
# makmur : makmur
# milan : mil
# tahapan : tahap
# abuse : abuse
# mkmk : mkmk
# berwenang : wenang
# membatalkan : batal
# keberlakuan : laku
# keabsahan : absah
# konstitusionalitas : konstitusionalitas
# syarat : syarat
# keterpenuhan : penuh
# sekretaris : sekretaris
# istri : istri
# serakah : serakah
# kendaraan : kendara
# kursi : kursi
# walikota : walikota
# bogor : bogor
# pilihannya : pilih
# pemiu : pemiu
# mempengaruhi : pengaruh
# elektabilitas : elektabilitas
# menetapkan : tetap
# queen : queen
# pamer : pamer
# stres : stres
# urat : urat
# putus : putus
# pengalaman : alam
# enam : enam
# reformasi : reformasi
# mengkhawatirkan : khawatir
# assalamualaikum : assalamualaikum
# baswedan : baswedan
# gus : gus
# iskandar : iskandar
# dicatat : catat
# kebaikan : baik
# berterima : terima
# kyai : kyai
# santri : santri
# kapoknya : kapok
# ditipu : tipu
# mulu : mulu
# menyisakan : sisa
# euforia : euforia
# diberkesan : kes
# rakyattungguputusanmk : rakyattungguputusanmk
# hakangket : hakangket
# mjd : mjd
# tuntutan : tuntut
# aspirasi : aspirasi
# dimain : main
# diharapkan : harap
# motor : motor
# pengungkapan : ungkap
# bias : bias
# puteri : puter
# memble : memble
# alias : alias
# mencla : mencla
# mencle : mencle
# achmad : achmad
# sodiki : sodiki
# dikabulkan : kabul
# wilayah : wilayah
# komunikasi : komunikasi
# kunci : kunci
# ersatuan : ersatuan
# menjalin : jalin
# merawat : rawat
# kedamaian : damai
# memajukan : maju
# pilpresusai_waktunyaberdamai : pilpresusai waktunyaberdamai
# codebue : codebue
# elclasico : elclasico
# roy : roy
# suryo : suryo
# hersubeno : hersubeno
# point : point
# legitimate : legitimate
# menikmati : nikmat
# ketuk : ketuk
# palu : palu
# bermata : mata
# umur : umur
# kesabaran : sabar
# berjuang : juang
# senyumi : senyum
# temukan : temu
# menangkan : menang
# pewartadigitalnusantara : pewartadigitalnusantara
# mantau : mantau
# worth : worth
# keeping : keeping
# tabs : tabs
# let : let
# help : help
# each : each
# other : other
# janji : janji
# kawan : kawan
# like : like
# retweet : retweet
# komentar : komentar
# back : back
# secepatnya : cepat
# terimakasih : terimakasih
# lancar : lancar
# pemiluamankonflik : pemiluamankonflik
# memalukan : malu
# penerima : terima
# sangsi : sangsi
# rampung : rampung
# laporan : lapor
# pelecehan : leceh
# seksual : seksual
# dipecat : pecat
# mengundurkan : undur
# tersandung : sandung
# coret : coret
# basmi : basmi
# keji : keji
# kejujuran : jujur
# kebenaran : benar
# hilang : hilang
# waspada : waspada
# hoaxs : hoaxs
# hoax : hoax
# penjahat : jahat
# koruptor : koruptor
# mei : mei
# nur : nur
# benuur : benuur
# real : real
# akalan : akal
# menyerang : serang
# paham : paham
# ditahun : tahun
# kecewanya : kecewa
# wujudkan : wujud
# sadar : sadar
# cepat : cepat
# lambat : lambat
# meledak : ledak
# membakar : bakar
# berjoget : joget
# ria : ria
# sepuasnya : puas
# mendukungnya : dukung
# sumur : sumur
# ladang : ladang
# numpang : numpang
# sepatu : sepatu
# move : move
# moveon : moveon
# indonesiabersatu : indonesiabersatu
# indonesiamaju : indonesiamaju
# aktif : aktif
# kandung : kandung
# dibawah : bawah
# dituduh : tuduh
# penegak : tegak
# berdasar : dasar
# kosnsisten : kosnsisten
# andil : andil
# mendidik : didik
# cerdas : cerdas
# berkwalitas : berkwalitas
# yabg : yabg
# peneliti : teliti
# senior : senior
# brin : brin
# siti : siti
# zuhro : zuhro
# cakep : cakep
# balesannya : balesannya
# membenarkan : benar
# hitungan : hitung
# poin : poin
# perkara : perkara
# depannya : depan
# good : good
# true : true
# sangketa : sangketa
# historical : historical
# mengindikasikan : indikasi
# memburuk : buruk
# pondasi : pondasi
# menjaga : jaga
# kestabilan : stabil
# kemajuan : maju
# pemiluberakhirdengandamai : pemiluberakhirdengandamai
# onana : onana
# coach : coach
# justin : justin
# koordinator : koordinator
# pusat : pusat
# badan : badan
# eksekutif : eksekutif
# hilmi : hilmi
# ash : ash
# shidiqi : shidiqi
# mengajak : ajak
# elemen : elemen
# pengawas : awas
# tingkatkan : tingkat
# professionalitas : professionalitas
# integritasnya : integritas
# putusanmk_kebaikanbersama : putusanmk kebaikanbersama
# chelsea : chelsea
# chika : chika
# mampus : mampus
# peluk : peluk
# belanda : belanda
# eks : eks
# kpk : kpk
# busyro : busyro
# muqoddas : muqoddas
# dampak : dampak
# goblok : goblok
# perbandingan : banding
# jaminan : jamin
# seandainya : anda
# logonya : logo
# kayanya : kaya
# rusuh : rusuh
# lumpuh : lumpuh
# gara-gara : gara-gara
# tantrum : tantrum
# ngetawain : ngetawain
# pikiran : pikir
# doang : doang
# xixi : xixi
# digubris : gubris
# mentah : mentah
# menentang : tentang
# respons : respons
# menangi : tang
# daniel : daniel
# yusmic : yusmic
# wapres : wapres
# diisi : isi
# pimpinan : pimpin
# berpihak : pihak
# kenegaraan : negara
# bilang : bilang
# bla : bla
# esensi : esensi
# keberisikan : isi
# kegaduhan : gaduh
# pengin : pengin
# selesaikan : selesai
# keberadaan : ada
# menangani : tangan
# parah : parah
# orba : orba
# masinton : masinton
# bergerak : gerak
# sinergi : sinergi
# terjalin : jalin
# keamanan : aman
# ketertiban : tertib
# pengawalan : awal
# penyampaian : sampai
# pengamanan : aman
# mengawal : awal
# kebebasan : bebas
# air : air
# membingungkan : bingung
# melarang : larang
# pengaruhi : pengaruh
# standart : standart
# ganda : ganda
# hahaha : hahaha
# seriusan : serius
# melenceng : lenceng
# prediksi : prediksi
# obrolin : obrolin
# teman : teman
# nongkrong : nongkrong
# kejadian : jadi
# semarak : semarak
# mencapai : capai
# puncaknya : puncak
# rangkaian : rangkai
# gonjang : gonjang
# ganjing : ganjing
# thread : thread
# manipulasi : manipulasi
# hasilpemilu : hasilpemilu
# manipulasisuarahakim : manipulasisuarahakim
# dijaga : jaga
# unun : unun
# masyatakat : masyatakat
# puas : puas
# terselenggaranya : selenggara
# tingkat : tingkat
# berasal : asal
# lapisan : lapis
# sosial : sosial
# marihormatiputusanmk : marihormatiputusanmk
# bio : bio
# maldini : maldini
# scudetto : scudetto
# komoditas : komoditas
# pemohon : mohon
# pres : pres
# dipakai : pakai
# tutup : tutup
# mata : mata
# cuci : cuci
# nurani : nurani
# plot : plot
# twist : twist
# kudu : kudu
# tatap : tatap
# aksi : aksi
# unjuk : unjuk
# menyusul : susul
# agenda : agenda
# indikasi : indikasi
# kawasan : kawasan
# monas : monas
# aksisidangputusanmk : aksisidangputusanmk
# kebijakan : bijak
# melakukannya : laku
# lurah : lurah
# penipuan : tipu
# menguasai : kuasa
# kroni : kroni
# background : background
# friend : friend
# samsul : samsul
# bubarkan : bubar
# hukumnya : hukum
# membela : bela
# tantangan : tantang
# polarisasi : polarisasi
# tajam : tajam
# disertai : serta
# retorika : retorika
# memecah : pecah
# belah : belah
# merajut : rajut
# persaudaraan : saudara
# solid : solid
# keharusan : harus
# melangkah : lang
# ditengah : tengah
# dinamika : dinamika
# bripda : bripda
# hamka : hamka
# desa : desa
# kalola : kalola
# maniangppajo : maniangppajo
# {'dana': 'dana', 'bansos': 'bansos', 'pemilu': 'milu', 'dikeluarkan': 'keluar', 'triliun': 'triliun', 'rupiah': 'rupiah', 'biarkan': 'biar', 'pejabat': 'jabat', 'memenangkan': 'menang', 'keluarganya': 'keluarga', 'gelontorkan': 'gelontor', 'uang': 'uang', 'negara': 'negara', 'eep': 'eep', 'gulingkanrezimgarong': 'gulingkanrezimgarong', 'breaking': 'breaking', 'news': 'news', 'membangun': 'bangun', 'negeri': 'negeri', 'keciduk': 'ciduk', 'foto': 'foto', 'zionis': 'zionis', 'suaranya': 'suara', 'kena': 'kena', 'boikot': 'boikot', 'pas': 'pas', 'kemarin': 'kemarin', 'ybs': 'ybs', 'berusaha': 'usaha', 'memperbaiki': 'baik', 'citra': 'citra', 'mendekati': 'dekat', 'palestina': 'palestina', 'comes': 'comes', 'end': 'end', 'ending': 'ending', 'too': 'too', 'little': 'little', 'finale': 'finale', 'close': 'close', 'jagat': 'jagat', 'silang': 'silang', 'edisi': 'edisi', 'khusus': 'khusus', 'zine': 'zine', 'artbook': 'artbook', 'pages': 'pages', 'all': 'all', 'editorial': 'editorial', 'art': 'art', 'posted': 'posted', 'doodles': 'doodles', 'wips': 'wips', 'concepts': 'concepts', 'essays': 'essays', 'experience': 'experience', 'peeks': 'peeks', 'get': 'get', 'below': 'below', 'menemukan': 'temu', 'kedepan': 'depan', 'tinggal': 'tinggal', 'disempurnakan': 'sempurna', 'era': 'era', 'orde': 'orde', 'barupun': 'baru', 'terulang': 'ulang', 'pemenang': 'menang', 'ditentukan': 'tentu', 'dilaksanakan': 'laksana', 'rakyat': 'rakyat', 'dipelihara': 'pelihara', 'miskin': 'miskin', 'bodoh': 'bodoh', 'kemenangan': 'menang', 'nepotisme': 'nepotisme', 'tau': 'tau', 'bikin': 'bikin', 'kali': 'kali', 'seru': 'seru', 'banget': 'banget', 'orang': 'orang', 'interest': 'interest', 'politik': 'politik', 'melek': 'melek', 'data': 'data', 'fakta': 'fakta', 'melawan': 'lawan', 'penguasa': 'kuasa', 'haus': 'haus', 'kekuasaan': 'kuasa', 'bangga': 'bangga', 'dibarisan': 'baris', 'apapun': 'apa', 'telh': 'telh', 'upayakan': 'upaya', 'trimakasih': 'trimakasih', 'rocky': 'rocky', 'gerung': 'gerung', 'bicara': 'bicara', 'hasil': 'hasil', 'putusan': 'putus', 'desending': 'desending', 'ajaib': 'ajaib', 'hakim': 'hakim', 'curang': 'curang', 'cacat': 'cacat', 'bawaan': 'bawa', 'mempertahankan': 'tahan', 'dalil': 'dalil', 'diputus': 'putus', 'paman': 'paman', 'usman': 'usman', 'watch': 'watch', 'alhamdulillah': 'alhamdulillah', 'prabowo': 'prabowo', 'gibran': 'gibran', 'resmi': 'resmi', 'ditetapkan': 'tetap', 'kpu': 'kpu', 'presiden': 'presiden', 'wakil': 'wakil', 'terpilih': 'pilih', 'periode': 'periode', 'terima': 'terima', 'kasih': 'kasih', 'indonesia': 'indonesia', 'penyelenggara': 'selenggara', 'tokoh': 'tokoh', 'agama': 'agama', 'prajurit': 'prajurit', 'tni': 'tni', 'polri': 'polri', 'relawan': 'rawan', 'rekan': 'rekan', 'pers': 'pers', 'jongos': 'jongos', 'celeng': 'celeng', 'lupa': 'lupa', 'jejak': 'jejak', 'digital': 'digital', 'wowo': 'wowo', 'menuntut': 'tuntut', 'kepanasan': 'panas', 'surat': 'surat', 'amicus': 'amicus', 'curiaenya': 'curiaenya', 'mega': 'mega', 'menjelang': 'jelang', 'juta': 'juta', 'dibagikan': 'bagi', 'kepala': 'kepala', 'mestinya': 'mesti', 'ribu': 'ribu', 'beras': 'beras', 'larinya': 'lari', 'menang': 'menang', 'kerusuhan': 'rusuh', 'kalah': 'kalah', 'mati': 'mati', 'luka': 'luka', 'ketahuan': 'tahu', 'kekalahan': 'kalah', 'kumpulnya': 'kumpul', 'kubu': 'kubu', 'mantan': 'mantan', 'pendukung': 'dukung', 'anies': 'anies', 'demo': 'demo', 'tolak': 'tolak', 'intervensi': 'intervensi', 'patung': 'patung', 'kuda': 'kuda', 'tempo': 'tempo', 'febri': 'febri', 'angga': 'angga', 'palguna': 'palguna', 'tempofoto': 'tempofoto', 'lahirlah': 'lahir', 'sistem': 'sistem', 'buruk': 'buruk', 'prinsip': 'prinsip', 'lakukanlah': 'laku', 'securang': 'curang', 'tanggung': 'tanggung', 'gentonglah': 'gentong', 'segentong': 'gentong', 'gentongnya': 'gentong', 'babilah': 'babi', 'sebabi': 'sebab', 'babinya': 'babi', 'hamid': 'hamid', 'seremoni': 'seremoni', 'focus': 'focus', 'presidenterpilih': 'presidenterpilih', 'text': 'text', 'kenaikan': 'naik', 'gaji': 'gaji', ...
# ------------------------
# Pandas Apply:   0%|          | 0/289 [00:00<?, ?it/s]
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  ...  \
# 0   in                      NaN            0  ...
# 1   in   Jakarta Capital Region           10  ...
# 2   in       Jakarta, Indonesia          205  ...
# 3   en                Indonesia            3  ...
# 4   in  Social Media Influencer            4  ...
#
#                                            tweet_url          user_id_str  \
# 0  https://twitter.com/dancersejati07/status/1783...  1605747132014637061
# 1  https://twitter.com/Mdy_Asmara1701/status/1783...  1334853481019056128
# 2  https://twitter.com/erlanishere/status/1782758...             69561307
# 3  https://twitter.com/meihqtsume/status/17834690...   830741903117217793
# 4  https://twitter.com/StefanAntonio__/status/178...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning  \
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...
#
#                                         case_folding  \
# 0   dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  breaking news pemilu usai saatnya bersama memb...
# 2  setelah keciduk foto ama zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   mereka telah menemukan caranya pemilu pemilu ...
#
#                                           tokenisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, ama, zionis, dan, sua...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                          normalisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, sama, zionis, dan, su...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                     stopword_removal  \
# 0  [dana, bansos, pemilu, dikeluarkan, triliun, r...
# 1        [breaking, news, pemilu, membangun, negeri]
# 2  [keciduk, foto, zionis, suaranya, kena, boikot...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [menemukan, pemilu, pemilu, kedepan, tinggal, ...
#
#                                             stemming
# 0  [dana, bansos, milu, keluar, triliun, rupiah, ...
# 1             [breaking, news, milu, bangun, negeri]
# 2  [ciduk, foto, zionis, suara, kena, boikot, pas...
# 3  [milu, comes, end, ending, too, little, finale...
# 4  [temu, milu, milu, depan, tinggal, sempurna, m...
#
# [5 rows x 22 columns]

# %% [markdown]
# 10. To Sentence. Mengubah bentuk list token pada kolom stemming menjadi sentence atau kalimat.

# %%
#To Sentence/Untokenized
stemming = tweets[['stemming']]

def to_fit_sentence(Tweets):
    Tweets = np.array(Tweets)
    Tweets = ' '.join(Tweets)

    return Tweets

tweets['to_sentence'] = tweets['stemming'].apply(lambda x: to_fit_sentence(x))
tweets.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1783121575493189864  Wed Apr 24 13:11:27 +0000 2024              16
# 1  1783468568279171301  Thu Apr 25 12:10:16 +0000 2024              37
# 2  1782758875621667152  Tue Apr 23 13:10:12 +0000 2024           14156
# 3  1783469087890481255  Thu Apr 25 12:12:20 +0000 2024             182
# 4  1782415122457309365  Mon Apr 22 14:24:15 +0000 2024             616
#
#                                            full_text               id_str  \
# 0   Dana bansos di tahun pemilu 2024 dikeluarkan ...  1783121575493189864
# 1  Breaking News - Pemilu Usai Saatnya Bersama Me...  1783468568279171301
# 2  Setelah keciduk foto ama Zionis dan suaranya k...  1782758875621667152
# 3  as pemilu 2024 comes to an end... i'm ending i...  1783469087890481255
# 4  . . Mereka telah menemukan caranya .. Pemilu-P...  1782415122457309365
#
#                                            image_url in_reply_to_screen_name  \
# 0  https://pbs.twimg.com/ext_tw_video_thumb/17831...                     NaN
# 1  https://pbs.twimg.com/ext_tw_video_thumb/17834...                     NaN
# 2    https://pbs.twimg.com/media/GL2hv66agAAAglB.jpg                     NaN
# 3    https://pbs.twimg.com/media/GMAnqiQasAEc3PM.jpg                     NaN
# 4  https://pbs.twimg.com/ext_tw_video_thumb/17824...                     NaN
#
#   lang                 location  quote_count  ...          user_id_str  \
# 0   in                      NaN            0  ...  1605747132014637061
# 1   in   Jakarta Capital Region           10  ...  1334853481019056128
# 2   in       Jakarta, Indonesia          205  ...             69561307
# 3   en                Indonesia            3  ...   830741903117217793
# 4   in  Social Media Influencer            4  ...  1529491450605768704
#
#           username                                        remove_user  \
# 0   dancersejati07   Dana bansos di tahun pemilu 2024 dikeluarkan ...
# 1   Mdy_Asmara1701  Breaking News - Pemilu Usai Saatnya Bersama Me...
# 2      erlanishere  Setelah keciduk foto ama Zionis dan suaranya k...
# 3       meihqtsume  as pemilu 2024 comes to an end... i'm ending i...
# 4  StefanAntonio__  . . Mereka telah menemukan caranya .. Pemilu-P...
#
#                                             cleaning  \
# 0   Dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  Breaking News Pemilu Usai Saatnya Bersama Memb...
# 2  Setelah keciduk foto ama Zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   Mereka telah menemukan caranya Pemilu Pemilu ...
#
#                                         case_folding  \
# 0   dana bansos tahun pemilu dikeluarkan mulai ad...
# 1  breaking news pemilu usai saatnya bersama memb...
# 2  setelah keciduk foto ama zionis dan suaranya k...
# 3   pemilu comes end ending too little finale clo...
# 4   mereka telah menemukan caranya pemilu pemilu ...
#
#                                           tokenisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, ama, zionis, dan, sua...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                          normalisasi  \
# 0  [dana, bansos, tahun, pemilu, dikeluarkan, mul...
# 1  [breaking, news, pemilu, usai, saatnya, bersam...
# 2  [setelah, keciduk, foto, sama, zionis, dan, su...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [mereka, telah, menemukan, caranya, pemilu, pe...
#
#                                     stopword_removal  \
# 0  [dana, bansos, pemilu, dikeluarkan, triliun, r...
# 1        [breaking, news, pemilu, membangun, negeri]
# 2  [keciduk, foto, zionis, suaranya, kena, boikot...
# 3  [pemilu, comes, end, ending, too, little, fina...
# 4  [menemukan, pemilu, pemilu, kedepan, tinggal, ...
#
#                                             stemming  \
# 0  [dana, bansos, milu, keluar, triliun, rupiah, ...
# 1             [breaking, news, milu, bangun, negeri]
# 2  [ciduk, foto, zionis, suara, kena, boikot, pas...
# 3  [milu, comes, end, ending, too, little, finale...
# 4  [temu, milu, milu, depan, tinggal, sempurna, m...
#
#                                          to_sentence
# 0  dana bansos milu keluar triliun rupiah biar ja...
# 1                   breaking news milu bangun negeri
# 2  ciduk foto zionis suara kena boikot pas milu k...
# 3  milu comes end ending too little finale close ...
# 4  temu milu milu depan tinggal sempurna milu era...
#
# [5 rows x 23 columns]

# %% [markdown]
# 11. Save kedalam csv

# %%
#simpan kedalam csv
tweets.to_csv('preprocessing-pemilu.csv', sep=',', index=False)

# %% [markdown]
# Link kamus normalisasi (colloquial-indonesian-lexicon.csv) : https://medium.com/@arie.pratama.s/bahasa-indonesia-open-sourced-nlp-resources-8cb394193238
